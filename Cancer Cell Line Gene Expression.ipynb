# %% [markdown]
# **Lakshmi Srujana Dandem**

# %% [markdown]
# In the 1980s, the [National Cancer Institute](http://cancer.gov) developed a set of 60 cancer cell lines, called [NCI60](http://www.broadinstitute.org/mpr/NCI60/NCI60.html). The original purpose was for screening potential anti-cancer drugs. Here you will examine gene expresion in these cell lines. More than 41,000 probes were used for each of the 60 cell lines. For convenience, the data are provided in `NCI60.csv` and `NCI60cells.csv`.<p/>
# `NCI60` is somewhat large -- 41,078 probes by 60 cell lines. Each of these 2,454,680 entries is a measure of how much a particular gene was expressed in one cell line.<p/>
# One clue that a gene is linked to cancer is differences in expression of that gene from one cancer type to another. Here's the wrangling involved in extracting the expression of TOP3A for each cell line.

# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.pyplot as plt
import matplotlib
import plotnine as p9

# %% [markdown]
# _Insert a line of code to read NCI60.csv into a dataframe named_ `Narrow`.

# %%
Narrow = pd.read_csv("NCI60.csv")

# %% [markdown]
# _Insert a line of code to visually inspect or verify the structure and data of_ `Narrow`

# %%
Narrow
# Out:
#            i   Probe  BR.MCF7  BR.MDA_MB_231  BR.HS578T  BR.BT_549  BR.T47D  \
# 0          1  AT_D_3    -7.45          -7.51      -7.30      -7.37    -6.15
# 1          2  AT_D_5    -7.05          -6.62      -6.88      -6.78    -7.18
# 2          3  AT_D_M    -7.05          -7.29      -7.30      -7.37    -7.61
# 3          4  AT_L_3    -7.32          -7.01      -7.22      -6.60    -7.45
# 4          5  AT_L_5    -7.38          -7.22      -7.30      -7.37    -7.70
# ...      ...     ...      ...            ...        ...        ...      ...
# 41073  41074     RC5    -7.38          -7.51      -6.94      -7.37    -7.74
# 41074  41075     RC6    -7.45          -7.51      -7.30      -6.34    -7.74
# 41075  41076     RC7    -7.22          -7.51      -7.30      -7.37    -7.74
# 41076  41077     RC8    -7.45          -7.51      -7.30      -7.37    -7.74
# 41077  41078     RC9    -7.45          -7.51      -7.30      -7.37    -7.74
#
#        CNS.SF_268  CNS.SF_295  CNS.SF_539  ...  PR.PC_3  PR.DU_145  RE.786_0  \
# 0           -7.16       -7.03       -7.44  ...    -6.88      -6.78     -7.25
# 1           -7.25       -7.22       -7.37  ...    -6.27      -7.04     -6.68
# 2           -6.56       -7.63       -7.44  ...    -6.45      -7.29     -7.25
# 3           -7.00       -7.32       -7.27  ...    -6.30      -7.01     -6.73
# 4           -7.25       -7.61       -7.44  ...    -6.48      -7.15     -7.06
# ...           ...         ...         ...  ...      ...        ...       ...
# 41073       -7.25       -7.63       -7.44  ...    -7.21      -7.00     -7.25
# 41074       -7.25       -7.63       -7.44  ...    -7.21      -7.30     -7.25
# 41075       -7.25       -7.63       -7.44  ...    -6.85      -7.30     -6.50
# 41076       -7.25       -7.63       -7.44  ...    -7.21      -7.22     -7.25
# 41077       -7.25       -7.63       -7.44  ...    -7.21      -7.30     -7.25
#
#        RE.A498  RE.ACHN  RE.CAKI_1  RE.RXF_393  RE.SN12C  RE.TK_10  RE.UO_31
# 0        -7.17    -6.51      -6.66       -6.53     -6.86     -7.03     -6.85
# 1        -6.83    -6.65      -6.61       -6.23     -6.74     -6.85     -6.67
# 2        -7.14    -6.53      -6.93       -6.17     -7.20     -6.93     -6.85
# 3        -6.50    -6.37      -6.54       -7.07     -6.86     -6.55     -6.67
# 4        -6.44    -6.47      -6.62       -7.00     -7.22     -6.89     -6.36
# ...        ...      ...        ...         ...       ...       ...       ...
# 41073    -7.17    -7.13      -7.00       -7.10     -7.22     -7.03     -7.03
# 41074    -7.17    -6.41      -7.00       -7.10     -7.21     -6.86     -7.23
# 41075    -7.17    -7.07      -6.81       -7.10     -7.18     -6.82     -6.58
# 41076    -7.17    -7.11      -6.68       -7.07     -7.21     -7.03     -6.53
# 41077    -7.17    -7.13      -7.00       -7.10     -7.26     -7.03     -7.36
#
# [41078 rows x 62 columns]

# %% [markdown]
# _Insert a line of code that will transform_ `Narrow` _from wide to narrow format. Use_ `Probe` _as the identifier variable._

# %%
Narrow = pd.melt(Narrow, id_vars='Probe')

# %% [markdown]
# _Insert a line of code to verify the structure and data of_ `Narrow`

# %%
Narrow
# Out:
#           Probe  variable  value
# 0        AT_D_3         i   1.00
# 1        AT_D_5         i   2.00
# 2        AT_D_M         i   3.00
# 3        AT_L_3         i   4.00
# 4        AT_L_5         i   5.00
# ...         ...       ...    ...
# 2505753     RC5  RE.UO_31  -7.03
# 2505754     RC6  RE.UO_31  -7.23
# 2505755     RC7  RE.UO_31  -6.58
# 2505756     RC8  RE.UO_31  -6.53
# 2505757     RC9  RE.UO_31  -7.36
#
# [2505758 rows x 3 columns]

# %% [markdown]
# _Insert a line of code to read_ `NCI60cells.csv` _into the variable_ `CellTypes`. We're only interested in the `cellLine` and `tissue` columns. Both of these operations could happen in one line, or two.

# %%
CellTypes = pd.read_csv("NCI60cells.csv")
CellTypes = CellTypes[['cellLine', 'tissue']]

# %% [markdown]
# _Insert a line of code to verify the structure and data of_ `CellTypes`

# %%
CellTypes
# Out:
#           cellLine               tissue
# 0          BR:MCF7               Breast
# 1    BR:MDA_MB_231               Breast
# 2        BR:HS578T               Breast
# 3        BR:BT_549               Breast
# 4          BR:T47D               Breast
# 5       CNS:SF_268                  CNS
# 6       CNS:SF_295                  CNS
# 7       CNS:SF_539                  CNS
# 8       CNS:SNB_19                  CNS
# 9       CNS:SNB_75                  CNS
# 10        CNS:U251                  CNS
# 11      CO:COLO205                Colon
# 12     CO:HCC_2998                Colon
# 13      CO:HCT_116                Colon
# 14       CO:HCT_15                Colon
# 15         CO:HT29                Colon
# 16         CO:KM12                Colon
# 17       CO:SW_620                Colon
# 18     LE:CCRF_CEM             Leukemia
# 19        LE:HL_60             Leukemia
# 20        LE:K_562             Leukemia
# 21       LE:MOLT_4             Leukemia
# 22    LE:RPMI_8226             Leukemia
# 23           LE:SR             Leukemia
# 24      ME:LOXIMVI             Melanoma
# 25     ME:MALME_3M             Melanoma
# 26          ME:M14             Melanoma
# 27     ME:SK_MEL_2             Melanoma
# 28    ME:SK_MEL_28             Melanoma
# 29     ME:SK_MEL_5             Melanoma
# 30     ME:UACC_257             Melanoma
# 31      ME:UACC_62             Melanoma
# 32   ME:MDA_MB_435             Melanoma
# 33        ME:MDA_N             Melanoma
# 34         LC:A549  Non-Small Cell Lung
# 35         LC:EKVX  Non-Small Cell Lung
# 36       LC:HOP_62  Non-Small Cell Lung
# 37       LC:HOP_92  Non-Small Cell Lung
# 38     LC:NCI_H226  Non-Small Cell Lung
# 39      LC:NCI_H23  Non-Small Cell Lung
# 40    LC:NCI_H322M  Non-Small Cell Lung
# 41     LC:NCI_H460  Non-Small Cell Lung
# 42     LC:NCI_H522  Non-Small Cell Lung
# 43       OV:IGROV1              Ovarian
# 44      OV:OVCAR_3              Ovarian
# 45      OV:OVCAR_4              Ovarian
# 46      OV:OVCAR_5              Ovarian
# 47      OV:OVCAR_8              Ovarian
# 48      OV:SK_OV_3              Ovarian
# 49  OV:NCI_ADR_RES              Ovarian
# 50         PR:PC_3             Prostate
# 51       PR:DU_145             Prostate
# 52        RE:786_0                Renal
# 53         RE:A498                Renal
# 54         RE:ACHN                Renal
# 55       RE:CAKI_1                Renal
# 56      RE:RXF_393                Renal
# 57        RE:SN12C                Renal
# 58        RE:TK_10                Renal
# 59        RE:UO_31                Renal

# %% [markdown]
# _Notice how the cellLine names in this file use_ `:` _rather than_ `.` _We need to fix this. Update the contents of_ `cellLine` _to replace_ `:` _with_ `.` _using_ `str.replace`. _You will likely need to escape the_ `:`.

# %%
CellTypes["cellLine"] = CellTypes["cellLine"].str.replace(":", '.')

# %% [markdown]
# _Insert a line of code to verify the structure and data of_ `CellTypes`

# %%
CellTypes
# Out:
#           cellLine               tissue
# 0          BR.MCF7               Breast
# 1    BR.MDA_MB_231               Breast
# 2        BR.HS578T               Breast
# 3        BR.BT_549               Breast
# 4          BR.T47D               Breast
# 5       CNS.SF_268                  CNS
# 6       CNS.SF_295                  CNS
# 7       CNS.SF_539                  CNS
# 8       CNS.SNB_19                  CNS
# 9       CNS.SNB_75                  CNS
# 10        CNS.U251                  CNS
# 11      CO.COLO205                Colon
# 12     CO.HCC_2998                Colon
# 13      CO.HCT_116                Colon
# 14       CO.HCT_15                Colon
# 15         CO.HT29                Colon
# 16         CO.KM12                Colon
# 17       CO.SW_620                Colon
# 18     LE.CCRF_CEM             Leukemia
# 19        LE.HL_60             Leukemia
# 20        LE.K_562             Leukemia
# 21       LE.MOLT_4             Leukemia
# 22    LE.RPMI_8226             Leukemia
# 23           LE.SR             Leukemia
# 24      ME.LOXIMVI             Melanoma
# 25     ME.MALME_3M             Melanoma
# 26          ME.M14             Melanoma
# 27     ME.SK_MEL_2             Melanoma
# 28    ME.SK_MEL_28             Melanoma
# 29     ME.SK_MEL_5             Melanoma
# 30     ME.UACC_257             Melanoma
# 31      ME.UACC_62             Melanoma
# 32   ME.MDA_MB_435             Melanoma
# 33        ME.MDA_N             Melanoma
# 34         LC.A549  Non-Small Cell Lung
# 35         LC.EKVX  Non-Small Cell Lung
# 36       LC.HOP_62  Non-Small Cell Lung
# 37       LC.HOP_92  Non-Small Cell Lung
# 38     LC.NCI_H226  Non-Small Cell Lung
# 39      LC.NCI_H23  Non-Small Cell Lung
# 40    LC.NCI_H322M  Non-Small Cell Lung
# 41     LC.NCI_H460  Non-Small Cell Lung
# 42     LC.NCI_H522  Non-Small Cell Lung
# 43       OV.IGROV1              Ovarian
# 44      OV.OVCAR_3              Ovarian
# 45      OV.OVCAR_4              Ovarian
# 46      OV.OVCAR_5              Ovarian
# 47      OV.OVCAR_8              Ovarian
# 48      OV.SK_OV_3              Ovarian
# 49  OV.NCI_ADR_RES              Ovarian
# 50         PR.PC_3             Prostate
# 51       PR.DU_145             Prostate
# 52        RE.786_0                Renal
# 53         RE.A498                Renal
# 54         RE.ACHN                Renal
# 55       RE.CAKI_1                Renal
# 56      RE.RXF_393                Renal
# 57        RE.SN12C                Renal
# 58        RE.TK_10                Renal
# 59        RE.UO_31                Renal

# %% [markdown]
# _Write a line of code to join the data in_ `Narrow` _and_ `CellTypes`_, storing the result back into_ `Narrow`. _You should be able to mostly match the figure below. It's OK if your column names are different, as long as you are consistent!_

# %%
Narrow = Narrow.rename(
    columns={"variable":"cellLine"})

Narrow = pd.merge(Narrow, CellTypes, on = "cellLine")

# %% [markdown]
# _Write a line of code to verify the structure and data in_ `Narrow`.

# %%
Narrow
# Out:
#           Probe  cellLine  value  tissue
# 0        AT_D_3   BR.MCF7  -7.45  Breast
# 1        AT_D_5   BR.MCF7  -7.05  Breast
# 2        AT_D_M   BR.MCF7  -7.05  Breast
# 3        AT_L_3   BR.MCF7  -7.32  Breast
# 4        AT_L_5   BR.MCF7  -7.38  Breast
# ...         ...       ...    ...     ...
# 2464675     RC5  RE.UO_31  -7.03   Renal
# 2464676     RC6  RE.UO_31  -7.23   Renal
# 2464677     RC7  RE.UO_31  -6.58   Renal
# 2464678     RC8  RE.UO_31  -6.53   Renal
# 2464679     RC9  RE.UO_31  -7.36   Renal
#
# [2464680 rows x 4 columns]

# %% [markdown]
# ![Table 1](Final/T1.png "Table 1")

# %% [markdown]
# _Insert a line of code to extract those rows from_ `Narrow` _corresponding to the Probe_ `TOP3A`_, storing the result into a variable named_ `Probe_TOP3A`

# %%
Probe_TOP3A = Narrow[Narrow["Probe"]=="TOP3A"]

# %% [markdown]
# _Write a line of code to verify the structure and data of_ `Probe_TOP3A`.

# %%
Probe_TOP3A
# Out:
#          Probe        cellLine  value               tissue
# 4688     TOP3A         BR.MCF7  -0.37               Breast
# 45766    TOP3A   BR.MDA_MB_231  -0.18               Breast
# 86844    TOP3A       BR.HS578T   0.32               Breast
# 127922   TOP3A       BR.BT_549   0.05               Breast
# 169000   TOP3A         BR.T47D  -0.31               Breast
# 210078   TOP3A      CNS.SF_268  -0.13                  CNS
# 251156   TOP3A      CNS.SF_295  -0.81                  CNS
# 292234   TOP3A      CNS.SF_539  -0.57                  CNS
# 333312   TOP3A      CNS.SNB_19  -0.58                  CNS
# 374390   TOP3A      CNS.SNB_75  -0.88                  CNS
# 415468   TOP3A        CNS.U251  -0.89                  CNS
# 456546   TOP3A      CO.COLO205  -0.99                Colon
# 497624   TOP3A     CO.HCC_2998  -0.66                Colon
# 538702   TOP3A      CO.HCT_116  -0.86                Colon
# 579780   TOP3A       CO.HCT_15  -0.75                Colon
# 620858   TOP3A         CO.HT29  -1.72                Colon
# 661936   TOP3A         CO.KM12  -1.49                Colon
# 703014   TOP3A       CO.SW_620  -0.79                Colon
# 744092   TOP3A     LE.CCRF_CEM  -0.53             Leukemia
# 785170   TOP3A        LE.HL_60  -1.34             Leukemia
# 826248   TOP3A        LE.K_562  -0.70             Leukemia
# 867326   TOP3A       LE.MOLT_4  -0.37             Leukemia
# 908404   TOP3A    LE.RPMI_8226  -0.09             Leukemia
# 949482   TOP3A           LE.SR   0.53             Leukemia
# 990560   TOP3A      ME.LOXIMVI  -0.33             Melanoma
# 1031638  TOP3A     ME.MALME_3M  -0.81             Melanoma
# 1072716  TOP3A          ME.M14  -0.93             Melanoma
# 1113794  TOP3A     ME.SK_MEL_2  -0.80             Melanoma
# 1154872  TOP3A    ME.SK_MEL_28  -0.90             Melanoma
# 1195950  TOP3A     ME.SK_MEL_5  -0.74             Melanoma
# 1237028  TOP3A     ME.UACC_257  -0.28             Melanoma
# 1278106  TOP3A      ME.UACC_62  -0.41             Melanoma
# 1319184  TOP3A   ME.MDA_MB_435  -0.06             Melanoma
# 1360262  TOP3A        ME.MDA_N  -0.31             Melanoma
# 1401340  TOP3A         LC.A549  -0.19  Non-Small Cell Lung
# 1442418  TOP3A         LC.EKVX  -1.15  Non-Small Cell Lung
# 1483496  TOP3A       LC.HOP_62  -0.15  Non-Small Cell Lung
# 1524574  TOP3A       LC.HOP_92  -1.93  Non-Small Cell Lung
# 1565652  TOP3A     LC.NCI_H226  -0.54  Non-Small Cell Lung
# 1606730  TOP3A      LC.NCI_H23  -0.80  Non-Small Cell Lung
# 1647808  TOP3A    LC.NCI_H322M  -0.39  Non-Small Cell Lung
# 1688886  TOP3A     LC.NCI_H460  -0.68  Non-Small Cell Lung
# 1729964  TOP3A     LC.NCI_H522  -2.50  Non-Small Cell Lung
# 1771042  TOP3A       OV.IGROV1  -0.52              Ovarian
# 1812120  TOP3A      OV.OVCAR_3  -0.58              Ovarian
# 1853198  TOP3A      OV.OVCAR_4  -1.39              Ovarian
# 1894276  TOP3A      OV.OVCAR_5  -1.00              Ovarian
# 1935354  TOP3A      OV.OVCAR_8  -0.97              Ovarian
# 1976432  TOP3A      OV.SK_OV_3  -1.66              Ovarian
# 2017510  TOP3A  OV.NCI_ADR_RES  -1.07              Ovarian
# 2058588  TOP3A         PR.PC_3  -1.29             Prostate
# 2099666  TOP3A       PR.DU_145  -0.67             Prostate
# 2140744  TOP3A        RE.786_0  -0.89                Renal
# 2181822  TOP3A         RE.A498  -0.66                Renal
# 2222900  TOP3A         RE.ACHN  -1.19                Renal
# 2263978  TOP3A       RE.CAKI_1  -0.43                Renal
# 2305056  TOP3A      RE.RXF_393  -1.23                Renal
# 2346134  TOP3A        RE.SN12C   0.85                Renal
# 2387212  TOP3A        RE.TK_10  -1.11                Renal
# 2428290  TOP3A        RE.UO_31  -1.26                Renal

# %% [markdown]
# _If you have made it this far, your data in_ `Probe_TOP3A` _should resemble Table 2. It's OK to have more columns or for the columns to have different names._
# ![Table 2](Final/T2.png "Table 2")

# %% [markdown]
# _Create a new dataframe named_ `SummaryStats` _that contains the mean, standard deviation and count of the expression data **in each cancer tissue type**._

# %%
Table_A = Probe_TOP3A.groupby("tissue")
SummaryStats = Table_A['value']
SummaryStats= SummaryStats.agg(['mean', 'std', 'count'])
SummaryStats
# Out:
#                          mean       std  count
# tissue
# Breast              -0.098000  0.283849      5
# CNS                 -0.643333  0.288975      6
# Colon               -1.037143  0.406354      7
# Leukemia            -0.416667  0.624617      6
# Melanoma            -0.557000  0.311129     10
# Non-Small Cell Lung -0.925556  0.805623      9
# Ovarian             -1.027143  0.407256      7
# Prostate            -0.980000  0.438406      2
# Renal               -0.740000  0.707410      8

# %% [markdown]
# _We need to convert the mean expression data using numpy's_ `exp` _function. Be sure that the standard deviation and count values are **not** converted!_ <p/>
#
# _Create a new column named_ `se` _that represents the standard error. The standard error is calculated as_
# \begin{equation*}
# \frac{standard\ deviation}{\sqrt {count}}
# \end{equation*}
# _for each group. This value will be used to calculate the error bars later._

# %%
SummaryStats["mean"] = np.exp(SummaryStats["mean"])
SummaryStats['se'] = SummaryStats['std']/np.sqrt(SummaryStats['count'])
SummaryStats
# Out:
#                          mean       std  count        se
# tissue
# Breast               0.906649  0.283849      5  0.126941
# CNS                  0.525538  0.288975      6  0.117974
# Colon                0.354466  0.406354      7  0.153587
# Leukemia             0.659241  0.624617      6  0.254999
# Melanoma             0.572925  0.311129     10  0.098388
# Non-Small Cell Lung  0.396311  0.805623      9  0.268541
# Ovarian              0.358028  0.407256      7  0.153928
# Prostate             0.375311  0.438406      2  0.310000
# Renal                0.477114  0.707410      8  0.250107

# %% [markdown]
# _Insert a line of code to verify the structure and data in_ `SummaryStats`. _It should resemble the table below (ours will be slightly different in that we're including standard deviation values). You will also see that_ `tissue` _became an index during our aggregation. Remove it as an index so that we have_ `tissue` _available to graph._

# %%
SummaryStats_B = SummaryStats.reset_index()
SummaryStats_B
# Out:
#                 tissue      mean       std  count        se
# 0               Breast  0.906649  0.283849      5  0.126941
# 1                  CNS  0.525538  0.288975      6  0.117974
# 2                Colon  0.354466  0.406354      7  0.153587
# 3             Leukemia  0.659241  0.624617      6  0.254999
# 4             Melanoma  0.572925  0.311129     10  0.098388
# 5  Non-Small Cell Lung  0.396311  0.805623      9  0.268541
# 6              Ovarian  0.358028  0.407256      7  0.153928
# 7             Prostate  0.375311  0.438406      2  0.310000
# 8                Renal  0.477114  0.707410      8  0.250107

# %% [markdown]
# ![Table 3](Final/T3.png "Table 3")

# %% [markdown]
# The figure below shows the mean expression data graphically. This sort of bar graph is often seen in the scientific literature, but that does not mean it is an effective presentation.
# ![Figure 1](Final/F1.png "Figure 1")
# _Insert code to generate a similar bar graph of mean gene expression from the_ `SummaryStats` _data frame._

# %%
(p9.ggplot(data = SummaryStats_B)+
 p9.aes(x = 'tissue', y= 'mean')+
 p9.xlab("tissue")+ p9.ylab("mean")+
 p9.geom_bar(stat="identity")+
 p9.theme(axis_text_x=p9.element_text(rotation=40, hjust=1)))
# Out:
# <ggplot: (150921778089)>

# %% [markdown]
# To judge from the figure, `TOP3A` is expressed more highly in breast cancer than in other cancer tissue types. <p/>
# But don't jump to conclusions! Expression differs even from one cell line to another of the same tissue type, as in the next figure.
# ![Figure 2](Final/F2.png "Figure 2")
# _Insert code below to do two things._
# * _We want to plot the_ `Probe_TOP3A` _mean expression data by tissue type. To do this, you'll need to convert the gene expression data in_ `Probe_TOP3A` _with_ `np.exp`.
# * _Plot your data like the example figure._

# %%
Probe_TOP3A = Probe_TOP3A.rename(
    columns={"value":"expression"})
Probe_TOP3A["expression_B"] = np.exp(Probe_TOP3A["expression"])
Probe_TOP3A
# Out:
#          Probe        cellLine  expression               tissue  expression_B
# 4688     TOP3A         BR.MCF7       -0.37               Breast      0.690734
# 45766    TOP3A   BR.MDA_MB_231       -0.18               Breast      0.835270
# 86844    TOP3A       BR.HS578T        0.32               Breast      1.377128
# 127922   TOP3A       BR.BT_549        0.05               Breast      1.051271
# 169000   TOP3A         BR.T47D       -0.31               Breast      0.733447
# 210078   TOP3A      CNS.SF_268       -0.13                  CNS      0.878095
# 251156   TOP3A      CNS.SF_295       -0.81                  CNS      0.444858
# 292234   TOP3A      CNS.SF_539       -0.57                  CNS      0.565525
# 333312   TOP3A      CNS.SNB_19       -0.58                  CNS      0.559898
# 374390   TOP3A      CNS.SNB_75       -0.88                  CNS      0.414783
# 415468   TOP3A        CNS.U251       -0.89                  CNS      0.410656
# 456546   TOP3A      CO.COLO205       -0.99                Colon      0.371577
# 497624   TOP3A     CO.HCC_2998       -0.66                Colon      0.516851
# 538702   TOP3A      CO.HCT_116       -0.86                Colon      0.423162
# 579780   TOP3A       CO.HCT_15       -0.75                Colon      0.472367
# 620858   TOP3A         CO.HT29       -1.72                Colon      0.179066
# 661936   TOP3A         CO.KM12       -1.49                Colon      0.225373
# 703014   TOP3A       CO.SW_620       -0.79                Colon      0.453845
# 744092   TOP3A     LE.CCRF_CEM       -0.53             Leukemia      0.588605
# 785170   TOP3A        LE.HL_60       -1.34             Leukemia      0.261846
# 826248   TOP3A        LE.K_562       -0.70             Leukemia      0.496585
# 867326   TOP3A       LE.MOLT_4       -0.37             Leukemia      0.690734
# 908404   TOP3A    LE.RPMI_8226       -0.09             Leukemia      0.913931
# 949482   TOP3A           LE.SR        0.53             Leukemia      1.698932
# 990560   TOP3A      ME.LOXIMVI       -0.33             Melanoma      0.718924
# 1031638  TOP3A     ME.MALME_3M       -0.81             Melanoma      0.444858
# 1072716  TOP3A          ME.M14       -0.93             Melanoma      0.394554
# 1113794  TOP3A     ME.SK_MEL_2       -0.80             Melanoma      0.449329
# 1154872  TOP3A    ME.SK_MEL_28       -0.90             Melanoma      0.406570
# 1195950  TOP3A     ME.SK_MEL_5       -0.74             Melanoma      0.477114
# 1237028  TOP3A     ME.UACC_257       -0.28             Melanoma      0.755784
# 1278106  TOP3A      ME.UACC_62       -0.41             Melanoma      0.663650
# 1319184  TOP3A   ME.MDA_MB_435       -0.06             Melanoma      0.941765
# 1360262  TOP3A        ME.MDA_N       -0.31             Melanoma      0.733447
# 1401340  TOP3A         LC.A549       -0.19  Non-Small Cell Lung      0.826959
# 1442418  TOP3A         LC.EKVX       -1.15  Non-Small Cell Lung      0.316637
# 1483496  TOP3A       LC.HOP_62       -0.15  Non-Small Cell Lung      0.860708
# 1524574  TOP3A       LC.HOP_92       -1.93  Non-Small Cell Lung      0.145148
# 1565652  TOP3A     LC.NCI_H226       -0.54  Non-Small Cell Lung      0.582748
# 1606730  TOP3A      LC.NCI_H23       -0.80  Non-Small Cell Lung      0.449329
# 1647808  TOP3A    LC.NCI_H322M       -0.39  Non-Small Cell Lung      0.677057
# 1688886  TOP3A     LC.NCI_H460       -0.68  Non-Small Cell Lung      0.506617
# 1729964  TOP3A     LC.NCI_H522       -2.50  Non-Small Cell Lung      0.082085
# 1771042  TOP3A       OV.IGROV1       -0.52              Ovarian      0.594521
# 1812120  TOP3A      OV.OVCAR_3       -0.58              Ovarian      0.559898
# 1853198  TOP3A      OV.OVCAR_4       -1.39              Ovarian      0.249075
# 1894276  TOP3A      OV.OVCAR_5       -1.00              Ovarian      0.367879
# 1935354  TOP3A      OV.OVCAR_8       -0.97              Ovarian      0.379083
# 1976432  TOP3A      OV.SK_OV_3       -1.66              Ovarian      0.190139
# 2017510  TOP3A  OV.NCI_ADR_RES       -1.07              Ovarian      0.343009
# 2058588  TOP3A         PR.PC_3       -1.29             Prostate      0.275271
# 2099666  TOP3A       PR.DU_145       -0.67             Prostate      0.511709
# 2140744  TOP3A        RE.786_0       -0.89                Renal      0.410656
# 2181822  TOP3A         RE.A498       -0.66                Renal      0.516851
# 2222900  TOP3A         RE.ACHN       -1.19                Renal      0.304221
# 2263978  TOP3A       RE.CAKI_1       -0.43                Renal      0.650509
# 2305056  TOP3A      RE.RXF_393       -1.23                Renal      0.292293
# 2346134  TOP3A        RE.SN12C        0.85                Renal      2.339647
# 2387212  TOP3A        RE.TK_10       -1.11                Renal      0.329559
# 2428290  TOP3A        RE.UO_31       -1.26                Renal      0.283654

# %%
(p9.ggplot(data= Probe_TOP3A)+
 p9.aes(x = "tissue", y = "expression_B")+
 p9.xlab("tissue")+ p9.ylab("expression")+
 p9.geom_point()+
 p9.theme(axis_text_x=p9.element_text(rotation=40, hjust=1)))
# Out:
# <ggplot: (150921803126)>

# %%
When looking at the individual cell lines, it's not so clear that `TOP3A` is expressed differently in breast cancer compared to the others.<p/>
The mean reflects the `Top3A` expression collectively within each tissue type. As such, the mean is a **statistic** (a calculated quantity giving a collective property for a set of cases). In order to compare different tissues to one another, some indication must be given for the precision of the mean. Clasically, this indication is provided by a **confidence interval** at the 95-percent level.<p/>
Write code to produce error bars on the plotted data. The tops and bottoms of the error bars should be two standard errors above and below the mean for each tissue. Your graph should look something like below. You will need to combine the data for `Top3A` with standard errors for the various tissues, somehow.<p/>
The 'secret sauce' to make this work in `matplotlib`'s `plt.errorbar`, which takes a number of parameters, including the `x` and `y` values (use the `mean` here), how far to extend the error bar (`standard error` * 2), and include `capsize=5, ls='none'` to put the horizontal lines on the ends of the error bars and to _not_ connect the data with a best-fit line.<p/>
Similarly, when using `plotnine`, calculate and use the `ymin` and `ymax` values for `geom_errorbar`.
![Figure 5](Final/F5.png "Figure 5")
# Out:
#   Input In [42]
#     When looking at the individual cell lines, it's not so clear that `TOP3A` is expressed differently in breast cancer compared to the others.<p/>
#          ^
# SyntaxError: invalid syntax

# %%
SummaryStats_B ["MinY"]= SummaryStats_B["mean"]-2*SummaryStats_B['se']
SummaryStats_B ["MaxY"]= SummaryStats_B["mean"]+2*SummaryStats_B['se']
SummaryStats_B
# Out:
#                 tissue      mean       std  count        se      MinY  \
# 0               Breast  0.906649  0.283849      5  0.126941  0.652767
# 1                  CNS  0.525538  0.288975      6  0.117974  0.289590
# 2                Colon  0.354466  0.406354      7  0.153587  0.047291
# 3             Leukemia  0.659241  0.624617      6  0.254999  0.149243
# 4             Melanoma  0.572925  0.311129     10  0.098388  0.376150
# 5  Non-Small Cell Lung  0.396311  0.805623      9  0.268541 -0.140771
# 6              Ovarian  0.358028  0.407256      7  0.153928  0.050172
# 7             Prostate  0.375311  0.438406      2  0.310000 -0.244689
# 8                Renal  0.477114  0.707410      8  0.250107 -0.023100
#
#        MaxY
# 0  1.160531
# 1  0.761485
# 2  0.661641
# 3  1.169238
# 4  0.769700
# 5  0.933393
# 6  0.665885
# 7  0.995311
# 8  0.977328

# %%
(p9.ggplot()+
 p9.xlab("tissue")+ p9.ylab("expression")+
 p9.geom_point(data= Probe_TOP3A, mapping = p9.aes(x = "tissue", y = "expression_B"))+
 p9.geom_errorbar(data = SummaryStats_B, mapping = p9.aes(x='tissue', ymin = 'MinY', ymax= 'MaxY'))+
 p9.theme(axis_text_x=p9.element_text(rotation=40, hjust=1)))
# Out:
# <ggplot: (150921842860)>

# %%
There are 32,344 distinct probes in `NCI60`. `TOP3A` in the above example was selected literally at random. Repeat the above analysis with a different probe (I'd recommend A_23_P61317, A_24_P190631, or A_23_P135646 -- sadly, this term we've run out of time to discover why!). Your goal is to create a graph for this probe like we just did with the error bars.
# Out:
#   Input In [45]
#     There are 32,344 distinct probes in `NCI60`. `TOP3A` in the above example was selected literally at random. Repeat the above analysis with a different probe (I'd recommend A_23_P61317, A_24_P190631, or A_23_P135646 -- sadly, this term we've run out of time to discover why!). Your goal is to create a graph for this probe like we just did with the error bars.
#           ^
# SyntaxError: invalid syntax

# %%
n = Narrow.groupby('Probe')
n.first(15)
# Out:
#             value
# Probe
# 3.8-1       -7.45
# 7A5         -4.63
# A1BG         0.94
# A2BP1       -7.41
# A2M         -7.12
# ...           ...
# hCG_32481   -0.85
# hCG_401283  -1.03
# tAKR        -6.91
# tcag7.1017  -3.65
# tcag7.1239   1.22
#
# [32344 rows x 1 columns]

# %%
ProbeA_23 = Narrow[Narrow["Probe"]=="A_23_P61317"]
ProbeA_23
# Out:
#                Probe        cellLine  value               tissue
# 15737    A_23_P61317         BR.MCF7  -7.45               Breast
# 56815    A_23_P61317   BR.MDA_MB_231  -7.51               Breast
# 97893    A_23_P61317       BR.HS578T  -7.30               Breast
# 138971   A_23_P61317       BR.BT_549  -7.37               Breast
# 180049   A_23_P61317         BR.T47D  -7.74               Breast
# 221127   A_23_P61317      CNS.SF_268  -7.25                  CNS
# 262205   A_23_P61317      CNS.SF_295  -7.63                  CNS
# 303283   A_23_P61317      CNS.SF_539  -7.44                  CNS
# 344361   A_23_P61317      CNS.SNB_19  -7.43                  CNS
# 385439   A_23_P61317      CNS.SNB_75  -7.65                  CNS
# 426517   A_23_P61317        CNS.U251  -7.56                  CNS
# 467595   A_23_P61317      CO.COLO205  -6.77                Colon
# 508673   A_23_P61317     CO.HCC_2998  -7.36                Colon
# 549751   A_23_P61317      CO.HCT_116  -7.11                Colon
# 590829   A_23_P61317       CO.HCT_15  -7.72                Colon
# 631907   A_23_P61317         CO.HT29  -7.07                Colon
# 672985   A_23_P61317         CO.KM12  -6.92                Colon
# 714063   A_23_P61317       CO.SW_620  -6.98                Colon
# 755141   A_23_P61317     LE.CCRF_CEM  -7.45             Leukemia
# 796219   A_23_P61317        LE.HL_60  -7.03             Leukemia
# 837297   A_23_P61317        LE.K_562  -7.28             Leukemia
# 878375   A_23_P61317       LE.MOLT_4  -7.24             Leukemia
# 919453   A_23_P61317    LE.RPMI_8226  -6.93             Leukemia
# 960531   A_23_P61317           LE.SR  -7.04             Leukemia
# 1001609  A_23_P61317      ME.LOXIMVI  -7.00             Melanoma
# 1042687  A_23_P61317     ME.MALME_3M  -7.05             Melanoma
# 1083765  A_23_P61317          ME.M14  -7.23             Melanoma
# 1124843  A_23_P61317     ME.SK_MEL_2  -7.22             Melanoma
# 1165921  A_23_P61317    ME.SK_MEL_28  -7.30             Melanoma
# 1206999  A_23_P61317     ME.SK_MEL_5  -7.11             Melanoma
# 1248077  A_23_P61317     ME.UACC_257  -7.30             Melanoma
# 1289155  A_23_P61317      ME.UACC_62  -7.32             Melanoma
# 1330233  A_23_P61317   ME.MDA_MB_435  -7.51             Melanoma
# 1371311  A_23_P61317        ME.MDA_N  -7.47             Melanoma
# 1412389  A_23_P61317         LC.A549  -7.06  Non-Small Cell Lung
# 1453467  A_23_P61317         LC.EKVX  -7.40  Non-Small Cell Lung
# 1494545  A_23_P61317       LC.HOP_62  -7.42  Non-Small Cell Lung
# 1535623  A_23_P61317       LC.HOP_92  -7.25  Non-Small Cell Lung
# 1576701  A_23_P61317     LC.NCI_H226  -7.23  Non-Small Cell Lung
# 1617779  A_23_P61317      LC.NCI_H23  -7.41  Non-Small Cell Lung
# 1658857  A_23_P61317    LC.NCI_H322M  -7.44  Non-Small Cell Lung
# 1699935  A_23_P61317     LC.NCI_H460  -7.29  Non-Small Cell Lung
# 1741013  A_23_P61317     LC.NCI_H522  -7.37  Non-Small Cell Lung
# 1782091  A_23_P61317       OV.IGROV1  -7.03              Ovarian
# 1823169  A_23_P61317      OV.OVCAR_3  -7.13              Ovarian
# 1864247  A_23_P61317      OV.OVCAR_4  -7.23              Ovarian
# 1905325  A_23_P61317      OV.OVCAR_5  -6.54              Ovarian
# 1946403  A_23_P61317      OV.OVCAR_8  -7.21              Ovarian
# 1987481  A_23_P61317      OV.SK_OV_3  -6.77              Ovarian
# 2028559  A_23_P61317  OV.NCI_ADR_RES  -7.30              Ovarian
# 2069637  A_23_P61317         PR.PC_3  -1.13             Prostate
# 2110715  A_23_P61317       PR.DU_145  -1.84             Prostate
# 2151793  A_23_P61317        RE.786_0  -7.25                Renal
# 2192871  A_23_P61317         RE.A498  -7.17                Renal
# 2233949  A_23_P61317         RE.ACHN  -7.13                Renal
# 2275027  A_23_P61317       RE.CAKI_1  -7.00                Renal
# 2316105  A_23_P61317      RE.RXF_393  -7.10                Renal
# 2357183  A_23_P61317        RE.SN12C  -7.26                Renal
# 2398261  A_23_P61317        RE.TK_10  -7.03                Renal
# 2439339  A_23_P61317        RE.UO_31  -7.36                Renal

# %%
 
Table_A = ProbeA_23.groupby("tissue")
SummaryStats = Table_A['value']
SummaryStats= SummaryStats.agg(['mean', 'std', 'count'])
SummaryStats

SummaryStats["mean"] = np.exp(SummaryStats["mean"])
SummaryStats['se'] = SummaryStats['std']/np.sqrt(SummaryStats['count'])
SummaryStats

SummaryStats_B = SummaryStats.reset_index()
SummaryStats_B
 
ProbeA_23 = ProbeA_23.rename(
    columns={"value":"expression"})
ProbeA_23["expression_B"] = np.exp(ProbeA_23["expression"])
ProbeA_23


SummaryStats_B ["MinY"]= SummaryStats_B["mean"]-2*SummaryStats_B['se']
SummaryStats_B ["MaxY"]= SummaryStats_B["mean"]+2*SummaryStats_B['se']
SummaryStats_B


(p9.ggplot()+
 p9.xlab("tissue")+ p9.ylab("expression")+
 p9.geom_point(data= ProbeA_23, mapping = p9.aes(x = "tissue", y = "expression_B"))+
 p9.geom_errorbar(data = SummaryStats_B, mapping = p9.aes(x='tissue', ymin = 'MinY', ymax= 'MaxY'))+
 p9.theme(axis_text_x=p9.element_text(rotation=40, hjust=1)))
# Out:
#                          mean       std  count
# tissue
# Breast              -7.474000  0.168612      5
# CNS                 -7.493333  0.150820      6
# Colon               -7.132857  0.316529      7
# Leukemia            -7.161667  0.194465      6
# Melanoma            -7.251000  0.166430     10
# Non-Small Cell Lung -7.318889  0.123940      9
# Ovarian             -7.030000  0.277789      7
# Prostate            -1.485000  0.502046      2
# Renal               -7.162500  0.122562      8
#                          mean       std  count        se
# tissue
# Breast               0.000568  0.168612      5  0.075406
# CNS                  0.000557  0.150820      6  0.061572
# Colon                0.000798  0.316529      7  0.119637
# Leukemia             0.000776  0.194465      6  0.079390
# Melanoma             0.000709  0.166430     10  0.052630
# Non-Small Cell Lung  0.000663  0.123940      9  0.041313
# Ovarian              0.000885  0.277789      7  0.104994
# Prostate             0.226502  0.502046      2  0.355000
# Renal                0.000775  0.122562      8  0.043332
#                 tissue      mean       std  count        se
# 0               Breast  0.000568  0.168612      5  0.075406
# 1                  CNS  0.000557  0.150820      6  0.061572
# 2                Colon  0.000798  0.316529      7  0.119637
# 3             Leukemia  0.000776  0.194465      6  0.079390
# 4             Melanoma  0.000709  0.166430     10  0.052630
# 5  Non-Small Cell Lung  0.000663  0.123940      9  0.041313
# 6              Ovarian  0.000885  0.277789      7  0.104994
# 7             Prostate  0.226502  0.502046      2  0.355000
# 8                Renal  0.000775  0.122562      8  0.043332
#                Probe        cellLine  expression               tissue  \
# 15737    A_23_P61317         BR.MCF7       -7.45               Breast
# 56815    A_23_P61317   BR.MDA_MB_231       -7.51               Breast
# 97893    A_23_P61317       BR.HS578T       -7.30               Breast
# 138971   A_23_P61317       BR.BT_549       -7.37               Breast
# 180049   A_23_P61317         BR.T47D       -7.74               Breast
# 221127   A_23_P61317      CNS.SF_268       -7.25                  CNS
# 262205   A_23_P61317      CNS.SF_295       -7.63                  CNS
# 303283   A_23_P61317      CNS.SF_539       -7.44                  CNS
# 344361   A_23_P61317      CNS.SNB_19       -7.43                  CNS
# 385439   A_23_P61317      CNS.SNB_75       -7.65                  CNS
# 426517   A_23_P61317        CNS.U251       -7.56                  CNS
# 467595   A_23_P61317      CO.COLO205       -6.77                Colon
# 508673   A_23_P61317     CO.HCC_2998       -7.36                Colon
# 549751   A_23_P61317      CO.HCT_116       -7.11                Colon
# 590829   A_23_P61317       CO.HCT_15       -7.72                Colon
# 631907   A_23_P61317         CO.HT29       -7.07                Colon
# 672985   A_23_P61317         CO.KM12       -6.92                Colon
# 714063   A_23_P61317       CO.SW_620       -6.98                Colon
# 755141   A_23_P61317     LE.CCRF_CEM       -7.45             Leukemia
# 796219   A_23_P61317        LE.HL_60       -7.03             Leukemia
# 837297   A_23_P61317        LE.K_562       -7.28             Leukemia
# 878375   A_23_P61317       LE.MOLT_4       -7.24             Leukemia
# 919453   A_23_P61317    LE.RPMI_8226       -6.93             Leukemia
# 960531   A_23_P61317           LE.SR       -7.04             Leukemia
# 1001609  A_23_P61317      ME.LOXIMVI       -7.00             Melanoma
# 1042687  A_23_P61317     ME.MALME_3M       -7.05             Melanoma
# 1083765  A_23_P61317          ME.M14       -7.23             Melanoma
# 1124843  A_23_P61317     ME.SK_MEL_2       -7.22             Melanoma
# 1165921  A_23_P61317    ME.SK_MEL_28       -7.30             Melanoma
# 1206999  A_23_P61317     ME.SK_MEL_5       -7.11             Melanoma
# 1248077  A_23_P61317     ME.UACC_257       -7.30             Melanoma
# 1289155  A_23_P61317      ME.UACC_62       -7.32             Melanoma
# 1330233  A_23_P61317   ME.MDA_MB_435       -7.51             Melanoma
# 1371311  A_23_P61317        ME.MDA_N       -7.47             Melanoma
# 1412389  A_23_P61317         LC.A549       -7.06  Non-Small Cell Lung
# 1453467  A_23_P61317         LC.EKVX       -7.40  Non-Small Cell Lung
# 1494545  A_23_P61317       LC.HOP_62       -7.42  Non-Small Cell Lung
# 1535623  A_23_P61317       LC.HOP_92       -7.25  Non-Small Cell Lung
# 1576701  A_23_P61317     LC.NCI_H226       -7.23  Non-Small Cell Lung
# 1617779  A_23_P61317      LC.NCI_H23       -7.41  Non-Small Cell Lung
# 1658857  A_23_P61317    LC.NCI_H322M       -7.44  Non-Small Cell Lung
# 1699935  A_23_P61317     LC.NCI_H460       -7.29  Non-Small Cell Lung
# 1741013  A_23_P61317     LC.NCI_H522       -7.37  Non-Small Cell Lung
# 1782091  A_23_P61317       OV.IGROV1       -7.03              Ovarian
# 1823169  A_23_P61317      OV.OVCAR_3       -7.13              Ovarian
# 1864247  A_23_P61317      OV.OVCAR_4       -7.23              Ovarian
# 1905325  A_23_P61317      OV.OVCAR_5       -6.54              Ovarian
# 1946403  A_23_P61317      OV.OVCAR_8       -7.21              Ovarian
# 1987481  A_23_P61317      OV.SK_OV_3       -6.77              Ovarian
# 2028559  A_23_P61317  OV.NCI_ADR_RES       -7.30              Ovarian
# 2069637  A_23_P61317         PR.PC_3       -1.13             Prostate
# 2110715  A_23_P61317       PR.DU_145       -1.84             Prostate
# 2151793  A_23_P61317        RE.786_0       -7.25                Renal
# 2192871  A_23_P61317         RE.A498       -7.17                Renal
# 2233949  A_23_P61317         RE.ACHN       -7.13                Renal
# 2275027  A_23_P61317       RE.CAKI_1       -7.00                Renal
# 2316105  A_23_P61317      RE.RXF_393       -7.10                Renal
# 2357183  A_23_P61317        RE.SN12C       -7.26                Renal
# 2398261  A_23_P61317        RE.TK_10       -7.03                Renal
# 2439339  A_23_P61317        RE.UO_31       -7.36                Renal
#
#          expression_B
# 15737        0.000581
# 56815        0.000548
# 97893        0.000676
# 138971       0.000630
# 180049       0.000435
# 221127       0.000710
# 262205       0.000486
# 303283       0.000587
# 344361       0.000593
# 385439       0.000476
# 426517       0.000521
# 467595       0.001148
# 508673       0.000636
# 549751       0.000817
# 590829       0.000444
# 631907       0.000850
# 672985       0.000988
# 714063       0.000930
# 755141       0.000581
# 796219       0.000885
# 837297       0.000689
# 878375       0.000717
# 919453       0.000978
# 960531       0.000876
# 1001609      0.000912
# 1042687      0.000867
# 1083765      0.000725
# 1124843      0.000732
# 1165921      0.000676
# 1206999      0.000817
# 1248077      0.000676
# 1289155      0.000662
# 1330233      0.000548
# 1371311      0.000570
# 1412389      0.000859
# 1453467      0.000611
# 1494545      0.000599
# 1535623      0.000710
# 1576701      0.000725
# 1617779      0.000605
# 1658857      0.000587
# 1699935      0.000682
# 1741013      0.000630
# 1782091      0.000885
# 1823169      0.000801
# 1864247      0.000725
# 1905325      0.001444
# 1946403      0.000739
# 1987481      0.001148
# 2028559      0.000676
# 2069637      0.323033
# 2110715      0.158817
# 2151793      0.000710
# 2192871      0.000769
# 2233949      0.000801
# 2275027      0.000912
# 2316105      0.000825
# 2357183      0.000703
# 2398261      0.000885
# 2439339      0.000636
#                 tissue      mean       std  count        se      MinY  \
# 0               Breast  0.000568  0.168612      5  0.075406 -0.150243
# 1                  CNS  0.000557  0.150820      6  0.061572 -0.122587
# 2                Colon  0.000798  0.316529      7  0.119637 -0.238475
# 3             Leukemia  0.000776  0.194465      6  0.079390 -0.158004
# 4             Melanoma  0.000709  0.166430     10  0.052630 -0.104550
# 5  Non-Small Cell Lung  0.000663  0.123940      9  0.041313 -0.081964
# 6              Ovarian  0.000885  0.277789      7  0.104994 -0.209104
# 7             Prostate  0.226502  0.502046      2  0.355000 -0.483498
# 8                Renal  0.000775  0.122562      8  0.043332 -0.085889
#
#        MaxY
# 0  0.151379
# 1  0.123701
# 2  0.240072
# 3  0.159556
# 4  0.105969
# 5  0.083290
# 6  0.210874
# 7  0.936502
# 8  0.087439
# <ggplot: (150921973736)>
